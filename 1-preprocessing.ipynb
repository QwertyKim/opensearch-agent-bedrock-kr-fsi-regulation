# %%
import pymupdf4llm

text = pymupdf4llm.to_markdown("kr-fsi-regulation.pdf")
# Out:
# Processing kr-fsi-regulation.pdf...
# [                                        ] (0/3[=                                       ] ( 1/3[==                                      ] ( 2/34[===                                     ] ( 3/3[====                                    ] ( 4/34[=====                                   ] ( 5/3=[=======                                 ] ( 6/3[========                                ] ( 7/34[=========                               ] ( 8/3[==========                              ] ( 9/34[===========                             ] (10/3[============                            ] (11/34=[==============                          ] (12/34[===============                         ] (13/3[================                        ] (14/34[=================                       ] (15/3[==================                      ] (16/34=[====================                    ] (17/34[=====================                   ] (18/3[======================                  ] (19/34[=======================                 ] (20/3[========================                ] (21/34[=========================               ] (22/3=[===========================             ] (23/3[============================            ] (24/34[=============================           ] (25/3[==============================          ] (26/34[===============================         ] (27/3[================================        ] (28/34=[==================================      ] (29/34[===================================     ] (30/3[====================================    ] (31/34[=====================================   ] (32/3[======================================  ] (33/34=[========================================] (34/34]

# %%
import re


chapter_pattern = r"(?P<text>(?P<pre_chapter>.*?(?=\n제1장))|(?P<chapter>제(?P<num>\d+)장)\s*(?P<title>.*?)\n(?P<content>.*?)(?=\n(?:제\d+장|부칙)|\Z)|(?P<annex>\n부칙)\s*(?P<annex_content>.*))"

chapter_chunks = []
for match in re.finditer(chapter_pattern, text, re.DOTALL):
    if match.group('pre_chapter'):
        chapter_chunks.append({
            'type': 'PreChapter',
            'content': match.group('pre_chapter').strip(),
            'text': match.group('text').strip()
        })
    elif match.group('chapter'):
        chapter_chunks.append({
            'type': 'Chapter',
            'chapter': match.group('num'),
            'title': match.group('title'),
            'content': match.group('content').strip(),
            'text': match.group('text').strip()
        })
    elif match.group('annex'):
        chapter_chunks.append({
            'type': 'Annex',
            'chapter': '부칙',
            'title': match.group('annex'),
            'content': match.group('annex_content').strip(),
            'text': match.group('text').strip()
        })

#for chunk in chapter_chunks:
#    print(f"{chunk['content']}")


for chunk in chapter_chunks:
    if chunk['type'] == 'PreChapter':
        print("####" * 50)
        print("PreChapter:")
        print(chunk['content'][:50])
        print("####" * 50)
    elif chunk['type'] == 'Chapter':
        print("-" * 50)
        print(f"장 번호: {chunk['chapter']}, 장 제목: {chunk['title']}")
        print(f"장 내용: {chunk['content'][:50]}")
        print("-" * 50)
    else:
        print("===" * 50)
        print(f"부칙 제목: {chunk['title']}")
        print(f"부칙 내용: {chunk['content'][:50]}")
        print("===" * 50)
# Out:
# ########################################################################################################################################################################################################
# PreChapter:
# # 전자금융감독규정
#
# [시행 2023. 1. 1.] [금융위원회고시 제2022-44호, 2
# ########################################################################################################################################################################################################
# --------------------------------------------------
# 장 번호: 1, 장 제목: 총칙
# 장 내용: 제2조(정의) 이 규정에서 사용하는 용어의 정의는 다음과 같다.
#
# 1. "전산실"이라 함은
# --------------------------------------------------
# --------------------------------------------------
# 장 번호: 2, 장 제목: 전자금융거래 당사자의 권리와 의무
# 장 내용: 제4조(확인에 필요한 구체적인 거래내용) 시행령 제7조제4항제6호에서 "금융위원회가 정하여
# --------------------------------------------------
# --------------------------------------------------
# 장 번호: 3, 장 제목: 전자금융거래의 안전성 확보 및 이용자 보호
# 장 내용: 제1절 통칙
#
# 제7조(전자금융거래 종류별 안전성 기준) 법 제21조제2항의 "금융위원회가
# --------------------------------------------------
# --------------------------------------------------
# 장 번호: 4, 장 제목: 전자금융업의 허가와 등록 및 업무
# 장 내용: 제1절 허가 및 등록의 대상과 절차
#
# 제42조(총발행잔액의 산정방법 등) ① 시행령 제15
# --------------------------------------------------
# --------------------------------------------------
# 장 번호: 5, 장 제목: 전자금융업무의 감독
# 장 내용: 제58조(금융회사의 정보기술부문 실태평가 등) ① 금융감독원장은 금융회사의 정보기술부문의
# --------------------------------------------------
# --------------------------------------------------
# 장 번호: 6, 장 제목: 보칙
# 장 내용: 제73조(정보기술부문 및 전자금융 사고보고) ① 금융회사 및 전자금융업자는 다음 각 호와
# --------------------------------------------------
# ======================================================================================================================================================
# 부칙 제목:
# 부칙
# 부칙 내용: <제2022-44호,2022.11.23.>
#
# 제1조(시행일) 이 규정은 2023년 1월 1
# ======================================================================================================================================================

# %%
# r"(?P<section>제(?P<num>\d+)절)\s*(?P<title>.*?)\n(?P<content>.*?)(?=\n(?:제\d+절|부칙)|\Z)",  # 절 패턴, 절 번호, 타이틀, 내용을 그룹으로 캡처
pattern = r"(?P<text>(?P<section>제(?P<num>\d+)절)[ ](?P<title>.*?)\n(?P<content>.*?)(?=\n?(?:제\d+절[ ]|$)))" #

section_chunks = []

for chapter in chapter_chunks:
    content = chapter['content']
        
    section_chunks.append(chapter)
    
    if re.search(r"(제1절)\s", content):
        for match in re.finditer(pattern, content, re.DOTALL):
            section = {}
            if chapter.get('chapter'):
                section['chapter'] = chapter.get('chapter')

            if match.group('section'):
                section['section'] = match.group('num').strip()
                section['title'] = match.group('title').strip()
                section['content'] = match.group('content').strip()
                section['text'] = match.group('text').strip()
                
                section_chunks.append(section)

for section in section_chunks:
    str = ""
    if section.get('chapter'):
        str += section['chapter'] + "장"
    if section.get('section'):
        str += section['section'] + "절"
        
    if section.get('title'):
        str += "(" + section['title'] + ")"
        
    if len(section['content']) > 30:
        str += " " + section['content'][:30].strip()
    else:
        str += " " + section['content'].strip()
        
    print(str)
# Out:
#  # 전자금융감독규정
#
# [시행 2023. 1. 1.] [
# 1장(총칙) 제2조(정의) 이 규정에서 사용하는 용어의 정의는 다음
# 2장(전자금융거래 당사자의 권리와 의무) 제4조(확인에 필요한 구체적인 거래내용) 시행령 제7조
# 3장(전자금융거래의 안전성 확보 및 이용자 보호) 제1절 통칙
#
# 제7조(전자금융거래 종류별 안전성 기준)
# 3장1절(통칙) 제7조(전자금융거래 종류별 안전성 기준) 법 제21조제
# 3장2절(인력, 조직 및 예산 부문) 제8조(인력, 조직 및 예산) ① 금융회사 또는 전자금
# 3장3절(시설부문) 제9조(건물에 관한 사항) 금융회사 또는 전자금융업자는
# 3장4절(정보기술부문) 제12조(단말기 보호대책) 금융회사 또는 전자금융업자는
# 3장5절(정보기술부문 내부통제) 제19조(정보기술부문 계획서 제출 절차 등) ① 시행령
# 3장6절(전자금융업무) 제34조(전자금융거래 시 준수사항) 금융회사 또는 전자
# 4장(전자금융업의 허가와 등록 및 업무) 제1절 허가 및 등록의 대상과 절차
#
# 제42조(총발행잔
# 4장1절(허가 및 등록의 대상과 절차) 제42조(총발행잔액의 산정방법 등) ① 시행령 제15조
# 4장2절(허가 및 등록의 세부요건) 제50조(인력 및 물적 시설 세부요건) ① 법 제28조
# 4장3절(전자금융업의 업무) 제56조(전자화폐 발행업자의 겸업가능 업무) 시행령 제
# 5장(전자금융업무의 감독) 제58조(금융회사의 정보기술부문 실태평가 등) ① 금융
# 6장(보칙) 제73조(정보기술부문 및 전자금융 사고보고) ① 금융회
# 부칙장(
# 부칙) <제2022-44호,2022.11.23.>
#
# 제1조(시

# %%
pattern = r"(?P<text>(?P<article>제(?P<num>\d+)조(?:의(?P<subnum>\d+))?)\((?P<title>[^)]*)\)\s*(?P<content>.*?)(?=\n?(?:제\d+조(?:의\d+)?)|$))"  # 조 패턴, 조 번호, 제목, 내용을 그룹으로 캡처

article_chunks = []

for section in section_chunks:
    content = section['content']
    
    for match in re.finditer(pattern, content, re.DOTALL):
        article = {}
        if section.get('chapter'):
            article['chapter'] = section.get('chapter')

        if section.get('section'):
            article['section'] = section.get('section')
        
        if match.group('article'):
            article['article'] = match.group('num').strip()
            
            if match.group('subnum'):
                article['sub-article'] = match.group('subnum').strip()

            article['title'] = match.group('title').strip()
            article['content'] = match.group('content').strip()
            article['text'] = match.group('text').strip()
            
            article_chunks.append(article)

for article in article_chunks:
    str = ""
    if article.get('chapter'):
        str += article['chapter'] + "장"
    if article.get('section'):
        str += article['section'] + "절 "
        
    if article.get('article'):
        str += article['article'] + "조"
        if article.get('sub-article'):
            str += "의" + article['sub-article']
    if article.get('title'):
        str += "(" + article['title'] + ") "
        
    if len(article['content']) > 30:
        str += " " + article['content'][:30].strip()
    else:
        str += " " + article['content'].strip()
        
    print(str)
# Out:
# 1조(목적)  이 규정은 「전자금융거래법」(이하 "법"이라 한다) 및
# 1장2조(정의)  이 규정에서 사용하는 용어의 정의는 다음과 같다.
#
# 1
# 1장3조(전자금융보조업자의 범위)  법
# 2장4조(확인에 필요한 구체적인 거래내용)  시행령
# 2장5조(전자금융사고 책임이행을 위한 보험 등의 가입에 관한 기준)  ① 금융회사 또는 전자금융업자가 법
# 2장6조(추심이체 출금 동의의 방법 등)  ① 시행령
# 2장6조의2(정보보호최고책임자의 지정대상)  ① 시행령
# 3장7조(전자금융거래 종류별 안전성 기준)  법
# 3장8조(인력, 조직 및 예산)  ① 금융회사 또는 전자금융업자는 인력 및 조직의 운용에
# 3장8조의2(정보보호위원회 운영)  ① 금융회사 또는 전자금융업자는 중요 정보보호에 관한
# 3장9조(건물에 관한 사항)  금융회사 또는 전자금융업자는 전산실이 위치한 건물에 관
# 3장10조(전원, 공조 등 설비에 관한 사항)  금융회사 또는 전자금융업자는 전산실이 위치한 건물의 전
# 3장11조(전산실 등에 관한 사항)  금융회사 또는 전자금융업자는 전산실에 관하여 다음 각
# 3장12조(단말기 보호대책)  금융회사 또는 전자금융업자는 단말기 보호를 위하여 다음
# 3장13조(전산자료 보호대책)  ① 금융회사 또는 전자금융업자는 전산자료의 유출, 파괴
# 3장14조(정보처리시스템 보호대책)  금융회사 또는 전자금융업자는 정보처리시스템의 안전한 운
# 3장14조의2(클라우드컴퓨팅서비스 이용절차 등)  ① 금융회사 또는 전자금융업자는 「클라우드컴퓨팅 발전
# 3장15조(해킹 등 방지대책)  ① 금융회사 또는 전자금융업자는 정보처리시스템 및 정보
# 3장16조(악성코드 감염 방지대책)  ① 금융회사 또는 전자금융업자는 악성코드 감염을 방지하
# 3장17조(홈페이지 등 공개용 웹서버 관리대책)  ① 금융회사 또는 전자금융업자는 공개용 웹서버의 안전한
# 3장18조(IP주소 관리대책)  금융회사 또는 전자금융업자는 정보제공자 주소(이하 "I
# 3장19조(정보기술부문 계획서 제출 절차 등)  ① 시행령
# 3장19조의2(정보보호 교육계획의 수립 시행)  ① 정보보호최고책임자는 임직원의 정보보호역량 강화를 위
# 3장20조(정보처리시스템 구축 및 전자금융거래 관련 사업 추진)  금융회사 또는 전자금융업자는 정보처리시스템 및
#
# 전자금
# 3장21조(정보처리시스템 구축 및 전자금융거래 관련 계약)  금융회사 또는 전자금융업자는 정보처리시스템 구축 및
# 3장22조(정보처리시스템 감리)  금융회사 또는 전자금융업자는 정보처리시스템의 안전성 및
# 3장23조(비상대책 등의 수립ㆍ운용)  ① 금융회사 또는 전자금융업자는 장애ㆍ재해ㆍ파업ㆍ테러
# 3장24조(비상대응훈련 실시)  ① 금융회사 또는 전자금융업자는
# 3장25조(정보처리시스템의 성능관리)  금융회사 또는 전자금융업자는 정보처리시스템의 장애예방
# 3장26조(직무의 분리)  금융회사 또는 전자금융업자는 다음 각 호의 업무에 대하
# 3장27조(전산원장 통제)  ① 금융기관 또는 전자금융업자는 장애 또는 오류 등에
# 3장28조(거래통제 등)  ① 금융회사 또는 전자금융업자는 사고위험도가 높은 거래
# 3장29조(프로그램 통제)  금융회사 또는 전자금융업자는 다음 각 호의 사항을 포함
# 3장30조(일괄작업에 대한 통제)  금융회사 또는 전자금융업자는 안전하고 체계적인 일괄작업
# 3장31조(암호프로그램 및 키 관리 통제)  ① 금융회사 또는 전자금융업자는 암호프로그램에 대하여
# 3장32조(내부사용자 비밀번호 관리)  금융회사 또는 전자금융업자는 내부사용자의 비밀번호 유출
# 3장33조(이용자 비밀번호 관리)  ① 금융회사 또는 전자금융업자는 정보처리시스템 및 전산
# 3장34조(전자금융거래 시 준수사항)  금융회사 또는 전자금융업자는 전자금융거래와 관련하여 다
# 3장35조(이용자 유의사항 공지)  금융회사 또는 전자금융업자는 전자금융거래의 안전한 수행
# 3장36조(자체 보안성심의)  ① 금융회사 또는 전자금융업자는 다음 각 호의 행위를
# 3장37조(인증방법 사용기준)  금융회사 또는 전자금융업자는 전자금융거래의 종류ㆍ성격ㆍ
# 3장37조의2(전자금융기반시설의 취약점 분석ㆍ평가 주기, 내용 등)  ① 전자금융기반시설의 취약점 분석ㆍ평가는 총
#
# 자산이
# 3장37조의3(전자금융기반시설의 취약점 분석ㆍ평가 전문기관의 지정 등)  ① 전자금융기반시설의 취약점 분석ㆍ평가
#
# 를 위한 평가
# 3장37조의4(침해사고대응기관 지정 및 업무범위 등)  ① 침해사고에 대응하기 위한 침해사고대응기관은 다음 각
# 3장37조의5(정보보호최고책임자의 업무)  정보보호최고책임자는 정보보안점검의 날을 지정하고, 임직
# 3장38조(금융위원회가 정하는 보관자료 및 거래기록 등)  시행령
# 3장39조(전자지급수단의 이용한도)  시행령
# 3장40조(약관교부 방법 등)  ① 전자금융업무를 수행하는 금융회사 및 전자금융업자는
# 3장41조(약관 제정 또는 변경에 따른 보고 등)  ① 법
# 3장1절 7조(전자금융거래 종류별 안전성 기준)  법
# 3장2절 8조(인력, 조직 및 예산)  ① 금융회사 또는 전자금융업자는 인력 및 조직의 운용에
# 3장2절 8조의2(정보보호위원회 운영)  ① 금융회사 또는 전자금융업자는 중요 정보보호에 관한
# 3장3절 9조(건물에 관한 사항)  금융회사 또는 전자금융업자는 전산실이 위치한 건물에 관
# 3장3절 10조(전원, 공조 등 설비에 관한 사항)  금융회사 또는 전자금융업자는 전산실이 위치한 건물의 전
# 3장3절 11조(전산실 등에 관한 사항)  금융회사 또는 전자금융업자는 전산실에 관하여 다음 각
# 3장4절 12조(단말기 보호대책)  금융회사 또는 전자금융업자는 단말기 보호를 위하여 다음
# 3장4절 13조(전산자료 보호대책)  ① 금융회사 또는 전자금융업자는 전산자료의 유출, 파괴
# 3장4절 14조(정보처리시스템 보호대책)  금융회사 또는 전자금융업자는 정보처리시스템의 안전한 운
# 3장4절 14조의2(클라우드컴퓨팅서비스 이용절차 등)  ① 금융회사 또는 전자금융업자는 「클라우드컴퓨팅 발전
# 3장4절 15조(해킹 등 방지대책)  ① 금융회사 또는 전자금융업자는 정보처리시스템 및 정보
# 3장4절 16조(악성코드 감염 방지대책)  ① 금융회사 또는 전자금융업자는 악성코드 감염을 방지하
# 3장4절 17조(홈페이지 등 공개용 웹서버 관리대책)  ① 금융회사 또는 전자금융업자는 공개용 웹서버의 안전한
# 3장4절 18조(IP주소 관리대책)  금융회사 또는 전자금융업자는 정보제공자 주소(이하 "I
# 3장5절 19조(정보기술부문 계획서 제출 절차 등)  ① 시행령
# 3장5절 19조의2(정보보호 교육계획의 수립 시행)  ① 정보보호최고책임자는 임직원의 정보보호역량 강화를 위
# 3장5절 20조(정보처리시스템 구축 및 전자금융거래 관련 사업 추진)  금융회사 또는 전자금융업자는 정보처리시스템 및
#
# 전자금
# 3장5절 21조(정보처리시스템 구축 및 전자금융거래 관련 계약)  금융회사 또는 전자금융업자는 정보처리시스템 구축 및
# 3장5절 22조(정보처리시스템 감리)  금융회사 또는 전자금융업자는 정보처리시스템의 안전성 및
# 3장5절 23조(비상대책 등의 수립ㆍ운용)  ① 금융회사 또는 전자금융업자는 장애ㆍ재해ㆍ파업ㆍ테러
# 3장5절 24조(비상대응훈련 실시)  ① 금융회사 또는 전자금융업자는
# 3장5절 25조(정보처리시스템의 성능관리)  금융회사 또는 전자금융업자는 정보처리시스템의 장애예방
# 3장5절 26조(직무의 분리)  금융회사 또는 전자금융업자는 다음 각 호의 업무에 대하
# 3장5절 27조(전산원장 통제)  ① 금융기관 또는 전자금융업자는 장애 또는 오류 등에
# 3장5절 28조(거래통제 등)  ① 금융회사 또는 전자금융업자는 사고위험도가 높은 거래
# 3장5절 29조(프로그램 통제)  금융회사 또는 전자금융업자는 다음 각 호의 사항을 포함
# 3장5절 30조(일괄작업에 대한 통제)  금융회사 또는 전자금융업자는 안전하고 체계적인 일괄작업
# 3장5절 31조(암호프로그램 및 키 관리 통제)  ① 금융회사 또는 전자금융업자는 암호프로그램에 대하여
# 3장5절 32조(내부사용자 비밀번호 관리)  금융회사 또는 전자금융업자는 내부사용자의 비밀번호 유출
# 3장5절 33조(이용자 비밀번호 관리)  ① 금융회사 또는 전자금융업자는 정보처리시스템 및 전산
# 3장6절 34조(전자금융거래 시 준수사항)  금융회사 또는 전자금융업자는 전자금융거래와 관련하여 다
# 3장6절 35조(이용자 유의사항 공지)  금융회사 또는 전자금융업자는 전자금융거래의 안전한 수행
# 3장6절 36조(자체 보안성심의)  ① 금융회사 또는 전자금융업자는 다음 각 호의 행위를
# 3장6절 37조(인증방법 사용기준)  금융회사 또는 전자금융업자는 전자금융거래의 종류ㆍ성격ㆍ
# 3장6절 37조의2(전자금융기반시설의 취약점 분석ㆍ평가 주기, 내용 등)  ① 전자금융기반시설의 취약점 분석ㆍ평가는 총
#
# 자산이
# 3장6절 37조의3(전자금융기반시설의 취약점 분석ㆍ평가 전문기관의 지정 등)  ① 전자금융기반시설의 취약점 분석ㆍ평가
#
# 를 위한 평가
# 3장6절 37조의4(침해사고대응기관 지정 및 업무범위 등)  ① 침해사고에 대응하기 위한 침해사고대응기관은 다음 각
# 3장6절 37조의5(정보보호최고책임자의 업무)  정보보호최고책임자는 정보보안점검의 날을 지정하고, 임직
# 3장6절 38조(금융위원회가 정하는 보관자료 및 거래기록 등)  시행령
# 3장6절 39조(전자지급수단의 이용한도)  시행령
# 3장6절 40조(약관교부 방법 등)  ① 전자금융업무를 수행하는 금융회사 및 전자금융업자는
# 3장6절 41조(약관 제정 또는 변경에 따른 보고 등)  ① 법
# 4장42조(총발행잔액의 산정방법 등)  ① 시행령
# 4장42조의2(거래금액 기준)  ① 법
# 4장43조(허가등 절차의 구분)  다음 각 호의 허가 또는 인가(이하 "허가등"이라 한다
# 4장44조(예비허가등)  ① 예비허가등을 신청하고자 하는 자는 금융감독원장이 정
# 4장45조(허가등)  ① 신청인은 예비허가등의 내용 및 조건을 이행한 후 금
# 4장46조(보완서류 등의 제출)  금융위원회는 예비허가등 또는 허가등의 심사 시 보완서류
# 4장47조(허가등 사실의 공고)  금융위원회는 허가등의 신청을 승인한 경우에는 지체 없이
# 4장48조(등록)  ① 법
# 4장49조(기재가 생략되는 출자자의 범위)  시행령
# 4장50조(인력 및 물적 시설 세부요건)  ① 법
# 4장50조의2(국외 사이버몰을 위한 전자지급결제대행업)  ①
# 4장51조(재무건전성 세부기준 및 계산방법 등)  ① 시행령
# 4장52조(사업계획에 관한 요건)  법
# 4장53조(주요출자자에 관한 요건)  주요출자자(시행령
# 4장54조(허가 및 등록신청 결격자)  법
# 4장55조(신청에 따른 등록말소 및 이용자 보호조치)  ① 법
# 4장56조(전자화폐 발행업자의 겸업가능 업무)  시행령
# 4장57조(수수료 및 준수사항 등의 고지방법)  법
# 4장1절 42조(총발행잔액의 산정방법 등)  ① 시행령
# 4장1절 42조의2(거래금액 기준)  ① 법
# 4장1절 43조(허가등 절차의 구분)  다음 각 호의 허가 또는 인가(이하 "허가등"이라 한다
# 4장1절 44조(예비허가등)  ① 예비허가등을 신청하고자 하는 자는 금융감독원장이 정
# 4장1절 45조(허가등)  ① 신청인은 예비허가등의 내용 및 조건을 이행한 후 금
# 4장1절 46조(보완서류 등의 제출)  금융위원회는 예비허가등 또는 허가등의 심사 시 보완서류
# 4장1절 47조(허가등 사실의 공고)  금융위원회는 허가등의 신청을 승인한 경우에는 지체 없이
# 4장1절 48조(등록)  ① 법
# 4장1절 49조(기재가 생략되는 출자자의 범위)  시행령
# 4장2절 50조(인력 및 물적 시설 세부요건)  ① 법
# 4장2절 50조의2(국외 사이버몰을 위한 전자지급결제대행업)  ①
# 4장2절 51조(재무건전성 세부기준 및 계산방법 등)  ① 시행령
# 4장2절 52조(사업계획에 관한 요건)  법
# 4장2절 53조(주요출자자에 관한 요건)  주요출자자(시행령
# 4장2절 54조(허가 및 등록신청 결격자)  법
# 4장2절 55조(신청에 따른 등록말소 및 이용자 보호조치)  ① 법
# 4장3절 56조(전자화폐 발행업자의 겸업가능 업무)  시행령
# 4장3절 57조(수수료 및 준수사항 등의 고지방법)  법
# 5장58조(금융회사의 정보기술부문 실태평가 등)  ① 금융감독원장은 금융회사의 정보기술부문의 건전성 여부
# 5장59조(검사결과의 보고방법)  금융감독원장은 법
# 5장60조(외부주문등에 대한 기준)  ① 금융회사 또는 전자금융업자는 전자금융거래를 위한 외
# 5장61조(전자금융보조업자 자료제출 기준)  ① 금융감독원장은 전자금융보조업자에 대해 외부주문등과
# 5장62조(업무보고서의 제출)  ① 법
# 5장63조(전자금융업자 경영지도기준)  ① 법
# 5장64조(경영개선권고)  ① 금융위원회는 법
# 5장65조(경영개선요구)  ① 금융위원회는 법
# 5장66조(경영개선명령)  ① 금융위원회는 법
# 5장67조(이유제시 등)
# 5장68조(적기시정조치의 유예)
# 5장69조(경영개선계획 제출 및 평가 등)  ①
# 5장70조(경영개선계획 이행기간 등)  ①
# 5장71조(경영개선계획의 불이행에 따른 조치)  금융위원회는
# 5장72조(과징금 수납기관 및 납부서식 등)  ① 시행령
# 5장72조의2(과징금 과오납에 따른 환급가산금 이율)  금융위원장은 「은행법」
# 6장73조(정보기술부문 및 전자금융 사고보고)  ① 금융회사 및 전자금융업자는 다음 각 호와 관련된 중
# 6장74조(위탁업무의 처리 결과 보고)  금융감독원장은 시행령
# 6장75조(규제의 존속기한 및 재검토)  ① 금융위원회는 「행정규제기본법」
# 부칙장1조(시행일)  이 규정은 2023년 1월 1일부터 시행한다.
#
#
# --

# %%
import unicodedata

pattern = r"\n?(?P<text>(?P<paragraph>[\u2460-\u24EA])\s*(?P<content>.*?)(?=(?:\n?[\u2460-\u24EA]\s*|$)))"  # 항 패턴, 항 번호, 내용을 그룹으로 캡처 

paragraph_chunks = []

for article in article_chunks:
    content = article['content']
    
    if content.startswith("금융위원회는 법"):
        print(content)
    
    if re.search(r"([\u2460-\u24EA])\s*", content):           
        for match in re.finditer(pattern, content, re.DOTALL):
            paragraph = {}
            
            if article.get('chapter') is not None:
                paragraph['chapter'] = article.get('chapter')
            if article.get('section') is not None:
                paragraph['section'] = article.get('section')
            if article.get('article') is not None:
                paragraph['article'] = article.get('article')
            if article.get('sub-article') is not None:
                paragraph['sub-article'] = article.get('sub-article')

            if match.group('paragraph'):
                paragraph['paragraph'] = f"{int(unicodedata.numeric(match.group('paragraph')))}"
                paragraph['content'] = match.group('content').strip()
                paragraph['text'] = match.group('text').strip()
                
                paragraph_chunks.append(paragraph)
    else:
        paragraph_chunks.append(article)


for paragraph in paragraph_chunks:
    str = ""
    if paragraph.get('chapter'):
        str += paragraph['chapter'] + "장"
    else:
        str += "  "
    if paragraph.get('section'):
        str += paragraph['section'] + "절"
        
    if paragraph.get('article'):
        str += paragraph['article'] + "조"
        if paragraph.get('sub-article'):
            str += "의" + paragraph['sub-article']
        
    if paragraph.get('paragraph'):
        str += "(" + paragraph['paragraph'] + "항)"
        
    if len(paragraph['content']) > 20:
        str += " " + paragraph['content'][:20].strip()
    else:
        str += " " + paragraph['content'].strip()
        
    print(str)
# Out:
#   1조 이 규정은 「전자금융거래법」(이하 "
# 1장2조 이 규정에서 사용하는 용어의 정의는
# 1장3조 법
# 2장4조 시행령
# 2장5조(1항) 금융회사 또는 전자금융업자가 법
# 2장6조(1항) 시행령
# 2장6조의2(1항) 시행령
# 3장7조 법
# 3장8조(1항) 금융회사 또는 전자금융업자는 인력 및
# 3장8조(2항) 금융회사 또는 전자금융업자는 인력 및
# 3장8조(3항) 제2항 각 호의 사항을 이행하지 못하
# 3장8조(4항) 제2항제1호의 인력에 관한 기준은 <
# 3장8조의2(1항) 금융회사 또는 전자금융업자는 중요 정
# 3장8조의2(2항) 정보보호위원회의 장은 정보보호최고책임
# 3장8조의2(3항) 정보보호위원회는 다음 각 호의 사항을
# 3장9조 금융회사 또는 전자금융업자는 전산실이
# 3장10조 금융회사 또는 전자금융업자는 전산실이
# 3장11조 금융회사 또는 전자금융업자는 전산실에
# 3장12조 금융회사 또는 전자금융업자는 단말기
# 3장13조(1항) 금융회사 또는 전자금융업자는 전산자료
# 4장1절44조(8항) 금융위원회는 합병, 영업양도 등 구조
# 4장1절45조(1항) 신청인은 예비허가등의 내용 및 조건을
# 4장1절45조(2항) 금융위원회는 허가등의 신청에 대하여
# 4장1절45조(3항) 허가등에는 조건을 붙일 수 있으며 허
# 4장1절45조(4항) 금융위원회는 예비허가등의 내용 및 조
# 4장1절45조(5항) 신청인은 예비허가등 또는 허가등 시에
# 4장1절46조 금융위원회는 예비허가등 또는 허가등의
# 4장1절47조 금융위원회는 허가등의 신청을 승인한
# 4장1절48조(1항) 법
# 4장1절49조 시행령
# 4장2절50조(1항) 법
# 4장2절50조의2(1항)
# 4장2절51조(1항) 시행령
# 4장2절52조 법
# 4장2절53조 주요출자자(시행령
# 4장2절54조 법
# 4장2절55조(1항) 법
# 4장3절56조 시행령
# 4장3절57조 법
# 5장58조(1항) 금융감독원장은 금융회사의 정보기술부문
# 5장58조(2항) 금융감독원장은 업무의 성격 및 규모,
# 5장58조(3항) 제2항에 의한 실태평가는 1등급(우수
# 5장58조(4항) 금융감독원장은 제2항에 따른 정보기술
# 5장58조(5항) 제4항의 확약서는 대표자의 승인을 받
# 5장58조(6항) 금융감독원장은 확약서 또는 양해각서의
# 5장58조(7항) 확약서 또는 양해각서의 효력발생일자,
# 5장58조(8항) 제2항에 따른 정보기술부문 실태평가
# 5장58조(9항) 제2항에 의한 정보기술부문의 실태평가
# 5장59조 금융감독원장은 법
# 5장60조(1항) 금융회사 또는 전자금융업자는 전자금융
# 5장61조(1항) 금융감독원장은 전자금융보조업자에 대해
# 5장61조(2항) 제1항에 따른 자료제출 요구시 전자금
# 5장62조(1항) 법
# 5장63조(1항) 법
# 5장64조(1항) 금융위원회는 법
# 5장65조(1항) 금융위원회는 법
# 5장66조(1항) 금융위원회는 법
# 5장67조
# 5장68조
# 5장69조(1항)
# 5장70조(1항)
# 5장71조 금융위원회는
# 5장72조(1항) 시행령
# 5장72조의2 금융위원장은 「은행법」
# 6장73조(1항) 금융회사 및 전자금융업자는 다음 각
# 6장74조 금융감독원장은 시행령
# 6장75조(1항) 금융위원회는 「행정규제기본법」
# 부칙장1조 이 규정은 2023년 1월 1일부터

# %%
pattern = r"\n(?P<text>(?P<clause>\d+)\.\s*(?P<content>.*?)(?=\n?\d+\.\s(?!\d+\.\s\d+\.)|$))" # 호 패턴

clause_chunks = []

for paragraph in paragraph_chunks:
    content = paragraph['content']
    
    content = re.sub(r'<.*?\n*.*?>', lambda match: match.group().replace('\n', ''), content)
    
    if re.search(r"\n?(1.)\s", content):
        for match in re.finditer(pattern, content, re.DOTALL):
            clause = {}
            if paragraph.get('chapter') is not None:
                clause['chapter'] = paragraph.get('chapter')
            if paragraph.get('section') is not None:
                clause['section'] = paragraph.get('section')
            if paragraph.get('article') is not None:
                clause['article'] = paragraph.get('article')
            if paragraph.get('sub-article') is not None:
                clause['sub-article'] = paragraph.get('sub-article')
            if paragraph.get('paragraph'):
                clause['paragraph'] = paragraph.get('paragraph')

            if match.group('clause'):
                clause['clause'] = match.group('clause')
                clause['content'] = match.group('content').strip()
                clause['text'] = match.group('text').strip()
                
                clause_chunks.append(clause)
    else:
        clause_chunks.append(paragraph)

for clause in clause_chunks:
    
    code = ""
    if clause.get('chapter'):
        if clause['chapter'] == "부칙":
            code += "부칙"
        else:
            code += "제" + clause['chapter'] + "장"
    if clause.get('section'):
        code += "제" + clause['section'] + "절"
        
    if clause.get('article'):
        code += "제" + clause['article'] + "조"
        if clause.get('sub-article'):
            code += "의" + clause['sub-article']
        
    if paragraph.get('paragraph'):
        code += "제" + paragraph['paragraph'] + "항"
        
    if clause.get('clause'):
        code += "제" + clause['clause'] + "호"
        
    str = ""
    if len(clause['content']) > 20:
       str += " " + clause['content'][:20].strip()
    else:
        str += " " + clause['content'].strip()
        
    clause['code'] = code
        
    print(f"{code} {str}")
# Out:
# 제1조  이 규정은 「전자금융거래법」(이하 "
# 제1장제2조제1호  "전산실"이라 함은 전산장비, 통신
# 제1장제2조제2호  "전산자료"라 함은 전산장비에 의해
# 제1장제2조제3호  "정보처리시스템"이라 함은 전자금융업
# 제1장제2조제4호  "정보기술부문"이라 함은 컴퓨터 등
# 제1장제2조제5호  "정보보호" 또는 "정보보안"이라 함
# 제1장제2조제6호  "정보보호시스템"이라 함은 정보처리시
# 제1장제2조제7호  "해킹"이라 함은 접근을 허가받지 아
# 제1장제2조제8호  "컴퓨터악성코드"(이하 "악성코드"라
# 제1장제2조제9호  "공개용 웹서버"라 함은 인터넷 이용
# 제1장제2조제10호  "정보통신망"(이하 "통신망"이라 한
# 제1장제2조제11호  삭제<2013.
# 제1장제3조  법
# 제2장제4조  시행령
# 제2장제5조  금융회사 또는 전자금융업자가 법
# 제2장제6조  시행령
# 제2장제6조의2  시행령
# 제3장제7조  법
# 제3장제8조제1호  정보처리시스템 및 전자금융업무 관련
# 제3장제8조제2호  외부주문등에 관한 계약을 체결하는 때
# 제3장제8조제3호  전산인력의 자질향상 및 예비요원 양성
# 제3장제8조제4호  정보보호최고책임자는 임직원이 정보보안
# 제3장제8조제5호  최고경영자는 임직원이 정보보안 관련법
# 제3장제8조제1호  정보기술부문 인력은 총 임직원수의 1
# 제3장제8조제2호  정보보호예산을 정보기술부문 예산의 1
# 제3장제8조  제2항제1호의 인력에 관한 기준은 <
# 제3장제8조의2  금융회사 또는 전자금융업자는 중요 정
# 제3장제8조의2  정보보호위원회의 장은 정보보호최고책임
# 제3장제8조의2제1호  법
# 제3장제9조제1호  건물 출입구는 경비원에 의하여 통제하
# 제3장제9조제2호  비상시 대피를 위한 비상계단 및 정전
# 제3장제9조제3호  번개, 과전류 등 고전압으로 인한 전
# 제3장제9조제4호  서버, 스토리지(Storage) 등
# 제3장제9조제5호  화재발생 시 조기진압을 위한 소화기
# 제3장제9조제6호  화재발생 위험이 높은 지역, 상습 침
# 제3장제10조제1호  전원실, 공조실 등 주요 설비시설에
# 제3장제10조제2호  전원, 공조, 방재 및 방범 설비에
# 제3장제10조제3호  전산실의 전력공급 중단에 대비하여 자
# 제3장제10조제4호  전력공급 장애 시 전력선 대체가 가능
# 제3장제10조제5호  과전류, 누전에 의한 장애 방지를 위
# 제3장제10조제6호  전산실에 공급되는 전원 및 공조 설비
# 제3장제10조제7호  전산실에 24시간 동안 적정한 온도
# 제3장제11조제1호  화재ㆍ수해 등의 재해 및 외부 위해(
# 제3장제11조제2호  상시 출입문은 한 곳으로 정하며 상시
# 제3장제11조제3호  상시 출입이 허용된 자 이외의 출입자
# 제3장제11조제4호  출입문은 이중 안전장치로 보호하며 외
# 제3장제11조제5호  천정ㆍ바닥ㆍ벽의 침수로 인한 정보처리
# 제3장제11조제6호  적정수준의 온도ㆍ습도를 유지하기 위하
# 제3장제11조제7호  케이블이 안전하게 유지되도록 전용 통
# 제3장제11조제8호  정전에 대비하여 조명설비 및 휴대용손
# 제3장제11조제9호  집적정보통신시설(Internet Da
# 제3장제11조제10호  다음 각 목의 중요 시설 및 지역을
# 제3장제11조제11호  국내에 본점을 둔 금융회사의 전산실
# 제3장제11조제12호  무선통신망을 설치하지 아니할 것
# 제3장제12조제1호  업무담당자 이외의 사람이 단말기를 무
# 제3장제12조제2호  정보처리시스템에 접속하는 단말기에 대
# 제3장제12조제3호  외부 반출, 인터넷 접속, 그룹웨어
# 제3장제12조제4호  정보유출, 악성코드 감염 등을 방지할
# 제3장제12조제5호  삭제<2015.
# 제3장제13조제1호  사용자계정과 비밀번호를 개인별로 부여
# 제3장제13조제2호  외부사용자에게 사용자계정을 부여하는
# 제3장제13조제3호  전산자료의 보유현황을 관리하고 책임자
# 제3장제13조제4호  전산자료의 입력ㆍ출력ㆍ열람을 함에 있
# 제3장제13조제5호  전산자료 및 전산장비의 반출ㆍ반입을
# 제3장제13조제6호  비상시에 대비하여 보조기억매체 등 전
# 제3장제13조제7호  정기적으로 보조기억매체의 보유 현황
# 제3장제13조제8호  중요도에 따라 전산자료를 정기적으로
# 제3장제13조제9호  주요 백업 전산자료에 대하여 정기적으
# 제3장제13조제10호  이용자 정보의 조회ㆍ출력에 대한 통제
# 제3장제13조제11호  정보처리시스템의 가동기록은 1년 이상
# 제3장제13조제12호  정보처리시스템 접속 시 5회 이내의
# 제3장제13조제13호  단말기에 이용자 정보 등 주요정보를
# 제3장제13조제14호  사용자가 전출ㆍ퇴직 등 인사조치가 있
# 제3장제13조  제1항제1호의 사용자계정의 공동 사용
# 제3장제13조제1호  정보처리시스템에 접속한 일시, 접속자
# 제3장제13조제2호  전산자료를 사용한 일시, 사용자 및
# 제3장제13조제3호  정보처리시스템내 전산자료의 처리 내용
# 제3장제13조  금융회사 또는 전자금융업자는 단말기와
# 제3장제14조제1호  주요 정보처리시스템에 대한 구동, 조
# 제3장제14조제2호  데이터베이스관리시스템(Database
# 제3장제14조제3호  정보처리시스템의 장애발생 시 장애일시
# 제3장제14조제4호  정보처리시스템의 정상작동여부 확인을
# 제3장제14조제5호  시스템 통합, 전환 및 재개발 시 장
# 제3장제14조제6호  정보처리시스템의 책임자를 지정ㆍ운영할
# 제3장제14조제7호  정보처리시스템의 운영체계, 시스템 유
# 제3장제14조제8호  중요도에 따라 정보처리시스템의 운영체
# 제3장제14조제9호  정보처리시스템의 운영체제(Operat
# 제3장제14조제10호  정보처리시스템 운영체제(Operati
# 제3장제14조의2  금융회사 또는 전자금융업자는 「클라우
# 제3장제15조제1호  해킹 등 전자적 침해행위로 인한 사고
# 제3장제15조제2호  해킹 등 전자적 침해행위에 대비한 시
# 제3장제15조제3호  내부통신망과 연결된 내부 업무용시스템
# 제3장제15조제4호  내부통신망에서의 파일 배포기능은 통합
# 제3장제15조제5호  전산실 내에 위치한 정보처리시스템과
# 제3장제15조제1호  삭제<2015.
# 제3장제15조제2호  최소한의 서비스번호(port)와 기능
# 제3장제15조제3호  보안정책의 승인ㆍ적용 및 보안정책의
# 제3장제15조제4호  정보보호시스템 원격관리를 금지할 것.
# 제3장제15조제5호  정보보호시스템의 작동 상태를 주기적으
# 제3장제15조제6호  시스템 장애, 가동중지 등 긴급사태에
# 제3장제15조  금융회사 또는 전자금융업자는 해킹 등
# 제3장제15조  삭제<2013. 12. 3.>
# 제3장제15조제1호  무선통신망 이용 업무는 최소한으로 국
# 제3장제16조제1호  응용프로그램을 사용할 때에는 악성코드
# 제3장제16조제2호  악성코드 검색 및 치료프로그램은 최신
# 제3장제16조제3호  악성코드 감염에 대비하여 복구 절차를
# 제3장제17조제1호  공개용 웹서버를 내부통신망과 분리하여
# 제3장제17조제2호  공개용 웹서버에 접근할 수 있는 사용
# 제3장제17조제3호  공개용 웹서버에서 제공하는 서비스를
# 제3장제17조제4호  DMZ구간 내에 이용자 정보 등 주요
# 제3장제17조제1호  게시자료에 대한 사전 내부통제 실시
# 제3장제17조제2호  무기명 또는 가명에 의한 게시 금지
# 제3장제17조제3호  홈페이지에 자료를 게시하는 담당자의
# 제3장제17조제4호  개인정보의 유출 및 위ㆍ변조를 방지하
# 제3장제17조  삭제<2013. 12. 3.>
# 제3장제17조  금융회사 또는 전자금융업자는 공개용
# 제3장제17조  금융회사 또는 전자금융업자는 단말기에
# 제3장제18조제1호  내부통신망에서 사용하는 IP주소의 경
# 제3장제18조제2호  개인별로 내부 IP주소를 부여하여 유
# 제3장제18조제3호  내부 IP주소 및 외부 IP주소의 인
# 제3장제18조제4호  정보처리시스템의 운영담당, 개발담당
# 제3장제18조제5호  내부통신망은 다른 기관 내부통신망과
# 제3장제19조  시행령
# 제3장제19조의2제1호  임원 : 3시간 이상(단, 정보보호최
# 제3장제19조의2제2호  일반직원 : 6시간 이상
# 제3장제19조의2제3호  정보기술부문업무 담당 직원 : 9시간
# 제3장제19조의2제4호  정보보호업무 담당 직원 : 12시간
# 제3장제19조의2  최고경영자는 정보보호교육을 실시한 이
# 제3장제19조의2  제1항의 교육프로그램 개발과 정보보호
# 제3장제20조제1호  조직에 미치는 영향이 크거나 내부직무
# 제3장제20조제2호  정보처리시스템의 신규 사업 및 통합ㆍ
# 제3장제29조제2호  프로그램 변경 전후 내용을 기록ㆍ관리
# 제3장제29조제3호  프로그램 등록ㆍ변경ㆍ폐기내용의 정당성
# 제3장제29조제4호  변경 필요시 해당 프로그램을 개발 또
# 제3장제29조제5호  프로그램에 대한 접근은 업무담당자에
# 제3장제29조제6호  운영시스템 적용은 처리하는 정보의 기
# 제3장제29조제7호  프로그램 반출, 실행프로그램의 생성
# 제3장제29조제8호  운영체제, 데이터베이스관리프로그램 등
# 제3장제29조제9호  프로그램 설명서, 입ㆍ출력 레코드 설
# 제3장제29조제10호  전자 금융거래에 사용되는 전산프로그램
# 제3장제30조제1호  일괄작업은 작업요청서에 의한 책임자의
# 제3장제30조제2호  일괄작업은 최대한 자동화하여 오류를
# 제3장제30조제3호  일괄작업 수행 과정에서 오류가 발생하
# 제3장제30조제4호  모든 일괄작업의 작업내용을 기록ㆍ관리
# 제3장제30조제5호  책임자는 일괄작업 수행자의 주요업무
# 제3장제31조  금융회사 또는 전자금융업자는 암호프로
# 제3장제31조  금융회사 또는 전자금융업자는 암호 및
# 제3장제32조제1호  담당업무 외에는 열람 및 출력을 제한
# 제3장제32조제2호  비밀번호는 다음 각 목의 사항을 준수
# 제3장제32조제3호  비밀번호 입력 시 5회 이내의 범위에
# 제3장제33조  금융회사 또는 전자금융업자는 정보처리
# 제3장제33조제1호  주민등록번호, 동일숫자, 연속숫자 등
# 제3장제33조제2호  통신용 비밀번호와 계좌원장 비밀번호를
# 제3장제33조제3호  5회 이내의 범위에서 미리 정한 횟수
# 제3장제33조제4호  금융회사가 이용자로부터 받은 비밀번호
# 제3장제33조제5호  신규 거래, 비밀번호 변경, 이체 신
# 제3장제34조제1호  전화 등 거래수단 성격상 암호화가 불
# 제3장제35조제1호  비밀번호 유출위험 및 관리에 관한 사
# 제3장제35조제2호  금융기관 또는 전자금융업자가 제공하고
# 제3장제35조제3호  해킹ㆍ피싱 등 전자적 침해 방지에 관
# 제3장제35조제4호  본인확인 절차를 거쳐 비밀번호 변경이
# 제3장제36조제1호  정보통신망을 이용하여 이용자를 대상으
# 제3장제36조제2호  복수의 금융회사 또는 전자금융업자가
# 제3장제36조  금융감독원장은 제2항에 따라 제출받은
# 제3장제36조제1호  「우체국예금ㆍ보험에 관한 법률」에 의
# 제3장제36조제2호  「새마을금고법」에 의한 새마을금고 및
# 제3장제36조제3호  「한국수출입은행법」에 따른 한국수출입
# 제3장제36조제4호  「공공기관의 운영에 관한 법률」
# 제3장제37조  금융회사 또는 전자금융업자는 전자금융
# 제3장제37조의2  금융회사 및 전자금융업자는 취약점 분
# 제3장제37조의3제1호  「정보통신기반 보호법」
# 제3장제37조의4제1호  금융보안원<개정 2015.
# 제3장제37조의4제2호  삭제<2015.
# 제3장제37조의4제3호  금융위원장이 지정한 자
# 제3장제37조의4제1호  침해사고에 관한 정보의 수집ㆍ전파를
# 제3장제37조의4제2호  침해사고의 예보ㆍ경보 발령내용의 전파
# 제3장제37조의4제3호  침해사고의 원인분석과 신속한 대응 및
# 제4장제1절제45조  신청인은 예비허가등 또는 허가등 시에
# 제4장제1절제46조  금융위원회는 예비허가등 또는 허가등의
# 제4장제1절제47조  금융위원회는 허가등의 신청을 승인한
# 제4장제1절제48조  법
# 제4장제1절제49조  시행령
# 제4장제2절제50조  법
# 제4장제2절제50조의2
# 제4장제2절제51조  시행령
# 제4장제2절제52조  법
# 제4장제2절제53조  주요출자자(시행령
# 제4장제2절제54조  법
# 제4장제2절제55조  법
# 제4장제3절제56조  시행령
# 제4장제3절제57조  법
# 제5장제58조  금융감독원장은 금융회사의 정보기술부문
# 제5장제58조  금융감독원장은 업무의 성격 및 규모,
# 제5장제58조  제2항에 의한 실태평가는 1등급(우수
# 제5장제58조  금융감독원장은 제2항에 따른 정보기술
# 제5장제58조  제4항의 확약서는 대표자의 승인을 받
# 제5장제58조  금융감독원장은 확약서 또는 양해각서의
# 제5장제58조  확약서 또는 양해각서의 효력발생일자,
# 제5장제58조  제2항에 따른 정보기술부문 실태평가
# 제5장제58조  제2항에 의한 정보기술부문의 실태평가
# 제5장제59조  금융감독원장은 법
# 제5장제60조제1호  외부주문등에 의한 정보처리시스템의 개
# 제5장제60조제2호  금융회사와 이용자 간 암호화정보 해독
# 제5장제60조제3호  계좌번호, 비밀번호 등 이용자 금융정
# 제5장제60조제4호  접근매체 위ㆍ변조, 해킹, 개인정보유
# 제5장제60조제5호  금융회사와 전자금융보조업자 간의 접속
# 제5장제60조제6호  정보처리시스템 장애 등 서비스 중단에
# 제5장제60조제7호  외부주문등의 입찰ㆍ계약ㆍ수행ㆍ완료 등
# 제5장제60조제8호  업무지속성을 위한 중요 전산자료의 백
# 제5장제60조제9호  정보관리의 취약점을 최소화하고 보안유
# 제5장제61조  금융감독원장은 전자금융보조업자에 대해
# 제5장제61조  제1항에 따른 자료제출 요구시 전자금
# 제5장제62조  법
# 제5장제63조  법
# 제5장제64조  금융위원회는 법
# 제5장제65조  금융위원회는 법
# 제5장제66조  금융위원회는 법
# 제5장제67조
# 제5장제68조
# 제5장제69조
# 제5장제70조
# 제5장제71조  금융위원회는
# 제5장제72조  시행령
# 제5장제72조의2  금융위원장은 「은행법」
# 제6장제73조제1호  정보처리시스템 또는 통신회선 등의 장
# 제6장제73조제2호  전산자료 또는 프로그램의 조작과 관련
# 제6장제73조제3호  전자적 침해행위로 인해 정보처리시스템
# 제6장제73조제4호  법
# 제6장제74조  금융감독원장은 시행령
# 제6장제75조  금융위원회는 「행정규제기본법」

# %%
pattern = r"(?P<text>(?P<item>[가나다라마바사아자차카타파하]?)\.\s*(?P<content>.*?)(?=\n?[가나다라마바사아자차카타파하]?\.\s*.*|$))" # 목 패턴 (?![가나다라마바사아자차카타파하]\.\n)

item_chunks = []

for clause in clause_chunks:
    content = clause['content']
    
    if re.search(r"\n(가.)\s", content):
        for match in re.finditer(pattern, content, re.DOTALL):
            item = {}
            if clause.get('chapter') is not None:
                item['chapter'] = clause.get('chapter')
            if clause.get('section') is not None:
                item['section'] = clause.get('section')
            if clause.get('article') is not None:
                item['article'] = clause.get('article')
            if clause.get('sub-article') is not None:
                item['sub-article'] = clause.get('sub-article')
            if clause.get('paragraph'):
                item['paragraph'] = clause.get('paragraph')
            if clause.get('clause'):
                item['clause'] = clause.get('clause')

            if match.group('item'):
                item['item'] = match.group('item')
                item['content'] = match.group('content').strip()
                item['text'] = match.group('text').strip()

                item_chunks.append(item)
    else:
        item_chunks.append(clause)
        

for item in item_chunks:
    
    code = ""
    if item.get('chapter'):
        if item['chapter'] == "부칙":
            code += "부칙"
        else:
            code += "제" + item['chapter'] + "장"
    if item.get('section'):
        code += "제" + item['section'] + "절"
        
    if item.get('article'):
        code += "제" + item['article'] + "조"
        if item.get('sub-article'):
            code += "의" + item['sub-article']
        
    if item.get('paragraph'):
        code += "제" + item['paragraph'] + "항"
        
    if item.get('clause'):
        code += "제" + item['clause'] + "호"
    if item.get('item'):
        str += "제" + item['item'] + "목"
        
    str = ""
    if len(item['content']) > 20:
       str += " " + item['content'][:20].strip()
    else:
        str += " " + item['content'].strip()
        
    item['code'] = code
        
    print(f"{code} {str}")
# Out:
# 제1조  이 규정은 「전자금융거래법」(이하 "
# 제1장제2조제1호  "전산실"이라 함은 전산장비, 통신
# 제1장제2조제2호  "전산자료"라 함은 전산장비에 의해
# 제1장제2조제3호  "정보처리시스템"이라 함은 전자금융업
# 제1장제2조제4호  "정보기술부문"이라 함은 컴퓨터 등
# 제1장제2조제5호  "정보보호" 또는 "정보보안"이라 함
# 제1장제2조제6호  "정보보호시스템"이라 함은 정보처리시
# 제1장제2조제7호  "해킹"이라 함은 접근을 허가받지 아
# 제1장제2조제8호  "컴퓨터악성코드"(이하 "악성코드"라
# 제1장제2조제9호  "공개용 웹서버"라 함은 인터넷 이용
# 제1장제2조제10호  "정보통신망"(이하 "통신망"이라 한
# 제1장제2조제11호  삭제<2013.
# 제1장제3조  법
# 제2장제4조  시행령
# 제2장제5조제1항  금융회사 또는 전자금융업자가 법
# 제2장제6조제1항  시행령
# 제2장제6조의2제1항  시행령
# 제3장제7조  법
# 제3장제8조제1항제1호  정보처리시스템 및 전자금융업무 관련
# 제3장제8조제1항제2호  외부주문등에 관한 계약을 체결하는 때
# 제3장제8조제1항제3호  전산인력의 자질향상 및 예비요원 양성
# 제3장제8조제1항제4호  정보보호최고책임자는 임직원이 정보보안
# 제3장제8조제1항제5호  최고경영자는 임직원이 정보보안 관련법
# 제3장제8조제2항제1호  정보기술부문 인력은 총 임직원수의 1
# 제3장제8조제2항제2호  정보보호예산을 정보기술부문 예산의 1
# 제3장제8조제4항  제2항제1호의 인력에 관한 기준은 <
# 제3장제8조의2제1항  금융회사 또는 전자금융업자는 중요 정
# 제3장제8조의2제2항  정보보호위원회의 장은 정보보호최고책임
# 제3장제8조의2제3항제1호  법
# 제3장제9조제1호  건물 출입구는 경비원에 의하여 통제하
# 제3장제9조제2호  비상시 대피를 위한 비상계단 및 정전
# 제3장제9조제3호  번개, 과전류 등 고전압으로 인한 전
# 제3장제13조제4항제1호  정보처리시스템에 접속한 일시, 접속자
# 제3장제13조제4항제2호  전산자료를 사용한 일시, 사용자 및
# 제3장제13조제4항제3호  정보처리시스템내 전산자료의 처리 내용
# 제3장제13조제5항  금융회사 또는 전자금융업자는 단말기와
# 제3장제14조제1호  주요 정보처리시스템에 대한 구동, 조
# 제3장제14조제2호  데이터베이스관리시스템(Database
# 제3장제14조제3호  정보처리시스템의 장애발생 시 장애일시
# 제3장제14조제4호  정보처리시스템의 정상작동여부 확인을
# 제3장제14조제5호  시스템 통합, 전환 및 재개발 시 장
# 제3장제14조제6호  정보처리시스템의 책임자를 지정ㆍ운영할
# 제3장제14조제7호  정보처리시스템의 운영체계, 시스템 유
# 제3장제14조제8호  중요도에 따라 정보처리시스템의 운영체
# 제3장제14조제9호  정보처리시스템의 운영체제(Operat
# 제3장제14조제10호  정보처리시스템 운영체제(Operati
# 제3장제14조의2제1항  금융회사 또는 전자금융업자는 「클라우
# 제3장제15조제1항제1호  해킹 등 전자적 침해행위로 인한 사고
# 제3장제15조제1항제2호  해킹 등 전자적 침해행위에 대비한 시
# 제3장제15조제1항제3호  내부통신망과 연결된 내부 업무용시스템
# 제3장제15조제1항제4호  내부통신망에서의 파일 배포기능은 통합
# 제3장제15조제1항제5호  전산실 내에 위치한 정보처리시스템과
# 제3장제15조제2항제1호  삭제<2015.
# 제3장제15조제2항제2호  최소한의 서비스번호(port)와 기능
# 제3장제15조제2항제3호  보안정책의 승인ㆍ적용 및 보안정책의
# 제3장제15조제2항제4호  정보보호시스템 원격관리를 금지할 것.
# 제3장제15조제2항제5호  정보보호시스템의 작동 상태를 주기적으
# 제3장제15조제2항제6호  시스템 장애, 가동중지 등 긴급사태에
# 제3장제15조제4항  금융회사 또는 전자금융업자는 해킹 등
# 제3장제15조제5항  삭제<2013. 12. 3.>
# 제3장제15조제6항제1호  무선통신망 이용 업무는 최소한으로 국
# 제3장제16조제1항제1호  응용프로그램을 사용할 때에는 악성코드
# 제3장제16조제1항제2호  악성코드 검색 및 치료프로그램은 최신
# 제3장제16조제1항제3호  악성코드 감염에 대비하여 복구 절차를
# 제3장제17조제1항제1호  공개용 웹서버를 내부통신망과 분리하여
# 제3장제17조제1항제2호  공개용 웹서버에 접근할 수 있는 사용
# 제3장제17조제1항제3호  공개용 웹서버에서 제공하는 서비스를
# 제3장제17조제1항제4호  DMZ구간 내에 이용자 정보 등 주요
# 제3장제17조제2항제1호  게시자료에 대한 사전 내부통제 실시
# 제3장제17조제2항제2호  무기명 또는 가명에 의한 게시 금지
# 제3장제17조제2항제3호  홈페이지에 자료를 게시하는 담당자의
# 제3장제17조제2항제4호  개인정보의 유출 및 위ㆍ변조를 방지하
# 제3장제17조제3항  삭제<2013. 12. 3.>
# 제3장제17조제4항  금융회사 또는 전자금융업자는 공개용
# 제3장제17조제5항  금융회사 또는 전자금융업자는 단말기에
# 제3장제18조제1호  내부통신망에서 사용하는 IP주소의 경
# 제3장제26조제1호  프로그래머와 오퍼레이터
# 제3장제26조제2호  응용프로그래머와 시스템프로그래머
# 제3장제26조제3호  시스템보안관리자와 시스템프로그래머
# 제3장제26조제4호  전산자료관리자(librarian)와
# 제3장제26조제5호  업무운영자와 내부감사자
# 제3장제26조제6호  내부인력과 전자금융보조업자 및 유지보
# 제3장제26조제7호  정보기술부문인력과 정보보호인력
# 제3장제26조제8호  그 밖에 내부통제와 관련하여 직무의
# 제3장제27조제1항  금융기관 또는 전자금융업자는 장애 또
# 제3장제27조제2항  제1항의 절차에는 변경 대상 및 방법
# 제3장제27조제3항  금융회사 또는 전자금융업자는 대차대조
# 제3장제27조제4항  금융회사 또는 전자금융업자는 제3항에
# 제3장제27조제5항  금융회사 또는 전자금융업자는 이용자
# 제3장제28조제1항  금융회사 또는 전자금융업자는 사고위험
# 제3장제28조제2항  금융회사 또는 전자금융업자는 전산원장
# 제3장제29조제1호  적용대상 프로그램 종류 및 등록ㆍ변경
# 제3장제29조제2호  프로그램 변경 전후 내용을 기록ㆍ관리
# 제3장제29조제3호  프로그램 등록ㆍ변경ㆍ폐기내용의 정당성
# 제3장제29조제4호  변경 필요시 해당 프로그램을 개발 또
# 제3장제29조제5호  프로그램에 대한 접근은 업무담당자에
# 제3장제29조제6호  운영시스템 적용은 처리하는 정보의 기
# 제3장제29조제7호  프로그램 반출, 실행프로그램의 생성
# 제3장제29조제8호  운영체제, 데이터베이스관리프로그램 등
# 제3장제29조제9호  프로그램 설명서, 입ㆍ출력 레코드 설
# 제3장제29조제10호  전자 금융거래에 사용되는 전산프로그램
# 제3장제30조제1호  일괄작업은 작업요청서에 의한 책임자의
# 제3장제30조제2호  일괄작업은 최대한 자동화하여 오류를
# 제3장제30조제3호  일괄작업 수행 과정에서 오류가 발생하
# 제3장제30조제4호  모든 일괄작업의 작업내용을 기록ㆍ관리
# 제3장제30조제5호  책임자는 일괄작업 수행자의 주요업무
# 제3장제31조제1항  금융회사 또는 전자금융업자는 암호프로
# 제3장제31조제2항  금융회사 또는 전자금융업자는 암호 및
# 제3장제32조제1호  담당업무 외에는 열람 및 출력을 제한
# 제3장제32조제2호  비밀번호는 이용자 식별부호(아이디),
# 제3장제32조제2호  비밀번호 보관 시 암호화
# 제3장제32조제2호  시스템마다 관리자 비밀번호를 다르게
# 제3장제32조제3호  비밀번호 입력 시 5회 이내의 범위에
# 제3장제33조제1항  금융회사 또는 전자금융업자는 정보처리
# 제3장제33조제2항제1호  주민등록번호, 동일숫자, 연속숫자 등
# 제3장제33조제2항제2호  통신용 비밀번호와 계좌원장 비밀번호를
# 제3장제33조제2항제3호  5회 이내의 범위에서 미리 정한 횟수
# 제3장제33조제2항제4호  금융회사가 이용자로부터 받은 비밀번호
# 제3장제33조제2항제5호  신규 거래, 비밀번호 변경, 이체 신
# 제3장제34조제1호  전화 등 거래수단 성격상 암호화가 불
# 제3장제35조제1호  비밀번호 유출위험 및 관리에 관한 사
# 제3장제35조제2호  금융기관 또는 전자금융업자가 제공하고
# 제4장제2절제54조  법
# 제4장제2절제55조제1항  법
# 제4장제3절제56조  시행령
# 제4장제3절제57조  법
# 제5장제58조제1항  금융감독원장은 금융회사의 정보기술부문
# 제5장제58조제2항  금융감독원장은 업무의 성격 및 규모,
# 제5장제58조제3항  제2항에 의한 실태평가는 1등급(우수
# 제5장제58조제4항  금융감독원장은 제2항에 따른 정보기술
# 제5장제58조제5항  제4항의 확약서는 대표자의 승인을 받
# 제5장제58조제6항  금융감독원장은 확약서 또는 양해각서의
# 제5장제58조제7항  확약서 또는 양해각서의 효력발생일자,
# 제5장제58조제8항  제2항에 따른 정보기술부문 실태평가
# 제5장제58조제9항  제2항에 의한 정보기술부문의 실태평가
# 제5장제59조  금융감독원장은 법
# 제5장제60조제1항제1호  외부주문등에 의한 정보처리시스템의 개
# 제5장제60조제1항제2호  금융회사와 이용자 간 암호화정보 해독
# 제5장제60조제1항제3호  계좌번호, 비밀번호 등 이용자 금융정
# 제5장제60조제1항제4호  접근매체 위ㆍ변조, 해킹, 개인정보유
# 제5장제60조제1항제5호  금융회사와 전자금융보조업자 간의 접속
# 제5장제60조제1항제6호  정보처리시스템 장애 등 서비스 중단에
# 제5장제60조제1항제7호  외부주문등의 입찰ㆍ계약ㆍ수행ㆍ완료 등
# 제5장제60조제1항제8호  업무지속성을 위한 중요 전산자료의 백
# 제5장제60조제1항제9호  정보관리의 취약점을 최소화하고 보안유
# 제5장제61조제1항  금융감독원장은 전자금융보조업자에 대해
# 제5장제61조제2항  제1항에 따른 자료제출 요구시 전자금
# 제5장제62조제1항  법
# 제5장제63조제1항  법
# 제5장제64조제1항  금융위원회는 법
# 제5장제65조제1항  금융위원회는 법
# 제5장제66조제1항  금융위원회는 법
# 제5장제67조
# 제5장제68조
# 제5장제69조제1항
# 제5장제70조제1항
# 제5장제71조  금융위원회는
# 제5장제72조제1항  시행령
# 제5장제72조의2  금융위원장은 「은행법」
# 제6장제73조제1항제1호  정보처리시스템 또는 통신회선 등의 장
# 제6장제73조제1항제2호  전산자료 또는 프로그램의 조작과 관련
# 제6장제73조제1항제3호  전자적 침해행위로 인해 정보처리시스템
# 제6장제73조제1항제4호  법
# 제6장제74조  금융감독원장은 시행령
# 제6장제75조제1항  금융위원회는 「행정규제기본법」

# %%
import json
with open('fsi-regulation.json', 'w') as f:
    json.dump(item_chunks, f)

# %%
import csv
from collections import OrderedDict

sorted_field = ["code", "chapter", "section", "paragraph", "article", "sub-article", "clause", "item"]

with open('fsi-regulation.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    
    # 모든 키를 포함하는 헤더 생성
    fieldnames = OrderedDict()
    for item in item_chunks:
        for key in item.keys():
            fieldnames[key] = None
            
    fieldnames = list(fieldnames.keys())
    # 키 순서 변경
    fieldnames = sorted_field + [key for key in fieldnames if key not in sorted_field]
    
    writer.writerow(fieldnames)
    
    # JSON 데이터의 각 요소를 CSV 파일에 행으로 작성
    for item in item_chunks:
        row = [item.get(field, '') for field in fieldnames]
        writer.writerow(row)
